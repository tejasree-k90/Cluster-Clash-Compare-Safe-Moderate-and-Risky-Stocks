# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# Load dataset
data = pd.read_csv('merged_data.csv')

# Step 1: Preprocessing
data['Date'] = pd.to_datetime(data['Date'], format='%d-%m-%Y')
data = data.dropna(subset=['GICS Sector'])
for col in ['environmentScore', 'socialScore', 'governanceScore', 'marketCap', 'beta', 'highestControversy']:
    data[col].fillna(data[col].median(), inplace=True)

# Step 2: Feature Engineering
data['volatility'] = (data['High'] - data['Low']) / data['Open']

def compute_rolling_features(group):
    group = group.sort_values('Date')
    group['returns'] = group['Close'].pct_change()
    group['hist_volatility'] = group['returns'].std() * np.sqrt(252)
    group['ma10'] = group['Close'].rolling(window=10, min_periods=5).mean()
    group['ma30'] = group['Close'].rolling(window=30, min_periods=10).mean()
    group['momentum'] = group['ma10'] / group['ma30']
    group['volume_norm'] = group['Volume'] / group['marketCap']
    return group

data = data.groupby('Symbol').apply(compute_rolling_features).reset_index(drop=True)

def compute_features(group):
    return pd.Series({
        'median_volatility': group['volatility'].median(),
        'hist_volatility': group['hist_volatility'].mean(),
        'mean_momentum': group['momentum'].mean(),
        'mean_volume_norm': group['volume_norm'].mean(),
        'environmentScore': group['environmentScore'].iloc[0],
        'socialScore': group['socialScore'].iloc[0],
        'governanceScore': group['governanceScore'].iloc[0],
        'marketCap': np.log1p(group['marketCap'].iloc[0]),
        'beta': group['beta'].iloc[0],
        'highestControversy': group['highestControversy'].iloc[0],
        'GICS_Sector': group['GICS Sector'].iloc[0]
    })

agg_data = data.groupby('Symbol').apply(compute_features).reset_index()
agg_data = agg_data.dropna()

agg_data['GICS_Sector_encoded'] = agg_data['GICS_Sector'].map(
    agg_data.groupby('GICS_Sector')['governanceScore'].mean()
)

# Step 3: Features for Clustering
features = [
    'median_volatility', 'hist_volatility', 'mean_momentum', 'mean_volume_norm',
    'environmentScore', 'socialScore', 'governanceScore', 'marketCap', 'beta',
    'highestControversy', 'GICS_Sector_encoded'
]
X = agg_data[features]

# Step 4: Preprocessing
preprocessor = ColumnTransformer(
    transformers=[('num', StandardScaler(), features)]
)
X_scaled = preprocessor.fit_transform(X)

# Step 5: Clustering Methods
methods = {
    'KMeans': {'model': KMeans(n_clusters=3, random_state=42), 'labels': None},
    'Hierarchical': {'model': AgglomerativeClustering(n_clusters=3), 'labels': None},
    'DBSCAN': {'model': None, 'labels': None}
}

# Define cluster label mappings based on previous analysis
cluster_mappings = {
    'KMeans': {1: 'Safe', 0: 'Moderate', 2: 'Risky'},  # K-Means: Cluster 1=Safe, 0=Moderate, 2=Risky
    'Hierarchical': {0: 'Safe', 1: 'Moderate', 2: 'Risky'},  # Hierarchical: Cluster 0=Safe, 1=Moderate, 2=Risky
    'DBSCAN': {0: 'Safe', 1: 'Moderate', -1: 'Risky'}  # DBSCAN: Cluster 0=Safe, 1=Moderate, Noise=Risky
}

# K-Means and Hierarchical Clustering
for method in ['KMeans', 'Hierarchical']:
    model = methods[method]['model']
    methods[method]['labels'] = model.fit_predict(X_scaled)
    methods[method]['sil_score'] = silhouette_score(X_scaled, methods[method]['labels'])
    print(f"\n{method} Results:")
    print(f"Number of Clusters: 3 (Safe, Moderate, Risky)")
    print(f"Silhouette Score: {methods[method]['sil_score']:.3f}")

# DBSCAN Clustering with Grid Search
eps_range = np.arange(0.5, 2.1, 0.5)
min_samples_range = [5, 10, 15]
best_eps = 0
best_min_samples = 0
best_sil_score = -1
results = []

for eps in eps_range:
    for min_samples in min_samples_range:
        dbscan = DBSCAN(eps=eps, min_samples=min_samples)
        labels = dbscan.fit_predict(X_scaled)
        n_clusters = len(set(labels)) - (1 if -1 in labels else 0)
        n_noise = list(labels).count(-1)
        if n_clusters > 1:
            sil_score = silhouette_score(X_scaled, labels)
        else:
            sil_score = -1
        results.append({
            'eps': eps,
            'min_samples': min_samples,
            'n_clusters': n_clusters,
            'n_noise': n_noise,
            'sil_score': sil_score
        })
        if sil_score > best_sil_score:
            best_sil_score = sil_score
            best_eps = eps
            best_min_samples = min_samples
            methods['DBSCAN']['labels'] = labels

methods['DBSCAN']['model'] = DBSCAN(eps=best_eps, min_samples=best_min_samples)
methods['DBSCAN']['labels'] = methods['DBSCAN']['model'].fit_predict(X_scaled)
methods['DBSCAN']['sil_score'] = best_sil_score
n_clusters_dbscan = len(set(methods['DBSCAN']['labels'])) - (1 if -1 in methods['DBSCAN']['labels'] else 0)
n_noise_dbscan = list(methods['DBSCAN']['labels']).count(-1)

print("\nDBSCAN Parameter Search Results:")
results_df = pd.DataFrame(results)
print(results_df.sort_values(by='sil_score', ascending=False).head())
print(f"\nBest DBSCAN Parameters: eps={best_eps}, min_samples={best_min_samples}")
print(f"Number of Clusters: {n_clusters_dbscan} (Safe, Moderate) + Risky (Noise)")
print(f"Number of Noise Points (Risky): {n_noise_dbscan}")
if n_clusters_dbscan > 1:
    print(f"Silhouette Score: {best_sil_score:.3f}")

# Step 6: Visualization (PCA for each method)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

for method in methods:
    # Map numeric labels to Safe, Moderate, Risky for plotting
    plot_labels = pd.Series(methods[method]['labels']).map(cluster_mappings[method]).values
    plt.figure(figsize=(8, 6))
    sns.scatterplot(
        x=X_pca[:, 0], y=X_pca[:, 1],
        hue=plot_labels, palette={'Safe': 'blue', 'Moderate': 'green', 'Risky': 'red'},
        style=plot_labels if method == 'DBSCAN' else None
    )
    plt.title(f'Clusters in 2D PCA Space ({method})')
    plt.xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.2%} variance)')
    plt.ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.2%} variance)')
    plt.legend(title='Cluster', loc='best')
    plt.show()

# Step 7: Interpret Clusters
for method in methods:
    print(f"\n{method} Cluster Interpretation:")
    # Map numeric labels to Safe, Moderate, Risky
    agg_data[f'Cluster_{method}'] = pd.Series(methods[method]['labels']).map(cluster_mappings[method]).values
    
    # Centroids
    cluster_summary = agg_data.groupby(f'Cluster_{method}')[features].mean()
    print("Cluster Centroids (Mean Feature Values):\n", cluster_summary.round(3))

    # Sector distribution
    sector_dist = agg_data.groupby([f'Cluster_{method}', 'GICS_Sector']).size().unstack(fill_value=0)
    print("\nSector Distribution per Cluster:\n", sector_dist)

    # Example companies
    print("\nExample Companies per Cluster:")
    for cluster in sorted(set(agg_data[f'Cluster_{method}'])):
        companies = agg_data[agg_data[f'Cluster_{method}'] == cluster]['Symbol'].head(5).tolist()
        print(f"{cluster}: {companies}")

# Step 8: Save Results
for method in methods:
    output_data = agg_data[['Symbol'] + features + ['GICS_Sector', f'Cluster_{method}']]
    output_data.to_csv(f'clustered___companies_{method.lower()}.csv', index=False)
    print(f"\nClustered data saved as 'clustered_companies_{method.lower()}.csv'")
# Out:
# KMeans Results:
# Number of Clusters: 3 (Safe, Moderate, Risky)
# Silhouette Score: 0.217
#
# Hierarchical Results:
# Number of Clusters: 3 (Safe, Moderate, Risky)
# Silhouette Score: 0.225
#
# DBSCAN Parameter Search Results:
#     eps  min_samples  n_clusters  n_noise  sil_score
# 10  2.0           10           2      106   0.197070
# 11  2.0           15           2      123   0.182558
# 9   2.0            5           3       87   0.131261
# 6   1.5            5           4      258  -0.034967
# 7   1.5           10           2      352  -0.057138
#
# Best DBSCAN Parameters: eps=2.0, min_samples=10
# Number of Clusters: 2 (Safe, Moderate) + Risky (Noise)
# Number of Noise Points (Risky): 106
# Silhouette Score: 0.197
# KMeans Cluster Interpretation:
# Cluster Centroids (Mean Feature Values):
#                  median_volatility  hist_volatility  mean_momentum  \
# Cluster_KMeans
# Moderate                    0.017            0.243          1.010
# Risky                       0.027            0.412          1.002
# Safe                        0.017            0.241          1.005
#
#                 mean_volume_norm  environmentScore  socialScore  \
# Cluster_KMeans
# Moderate                     0.0             1.708       10.039
# Risky                        0.0             6.500        9.369
# Safe                         0.0             6.894        8.754
#
#                 governanceScore  marketCap   beta  highestControversy  \
# Cluster_KMeans
# Moderate                  8.745     24.945  1.041               1.854
# Risky                     5.531     23.926  1.467               1.703
# Safe                      4.675     24.534  0.939               1.793
#
#                 GICS_Sector_encoded
# Cluster_KMeans
# Moderate                      8.466
# Risky                         4.973
# Safe                          4.940
#
# Sector Distribution per Cluster:
#  GICS_Sector     Communication Services  Consumer Discretionary  \
# Cluster_KMeans
# Moderate                             8                       0
# Risky                                4                      24
# Safe                                 7                      26
#
# GICS_Sector     Consumer Staples  Energy  Financials  Health Care  \
# Cluster_KMeans
# Moderate                       0       0          69            4
# Risky                          5       6           0           13
# Safe                          30      16           0           42
#
# GICS_Sector     Industrials  Information Technology  Materials  Real Estate  \
# Cluster_KMeans
# Moderate                  0                       1          0            0
# Risky                    13                      23          7            2
# Safe                     62                      42         20           28
#
# GICS_Sector     Utilities
# Cluster_KMeans
# Moderate                0
# Risky                   4
# Safe                   27
#
# Example Companies per Cluster:
# Moderate: ['AAPL', 'ABBV', 'ACGL', 'AFL', 'AIG']
# Risky: ['ABNB', 'AES', 'ALB', 'ALGN', 'AMAT']
# Safe: ['A', 'ABT', 'ACN', 'ADBE', 'ADI']
#
# Hierarchical Cluster Interpretation:
# Cluster Centroids (Mean Feature Values):
#                        median_volatility  hist_volatility  mean_momentum  \
# Cluster_Hierarchical
# Moderate                          0.017            0.243          1.010
# Risky                             0.028            0.417          0.992
# Safe                              0.019            0.273          1.005
#
#                       mean_volume_norm  environmentScore  socialScore  \
# Cluster_Hierarchical
# Moderate                         0.000             1.658        9.737
# Risky                            0.001             7.333        8.234
# Safe                             0.000             6.568        9.054
#
#                       governanceScore  marketCap   beta  highestControversy  \
# Cluster_Hierarchical
# Moderate                        9.003     24.593  1.055               1.657
# Risky                           5.518     23.146  1.562               1.929
# Safe                            4.950     24.553  1.033               1.796
#
#                       GICS_Sector_encoded
# Cluster_Hierarchical
# Moderate                            8.912
# Risky                               4.990
# Safe                                5.004
#
# Sector Distribution per Cluster:
#  GICS_Sector           Communication Services  Consumer Discretionary  \
# Cluster_Hierarchical
# Moderate                                   0                       0
# Risky                                      4                       7
# Safe                                      15                      43
#
# GICS_Sector           Consumer Staples  Energy  Financials  Health Care  \
# Cluster_Hierarchical
# Moderate                             0       0          67            0
# Risky                                2       1           0            2
# Safe                                33      21           2           57
#
# GICS_Sector           Industrials  Information Technology  Materials  \
# Cluster_Hierarchical
# Moderate                        0                       0          0
# Risky                           1                       4          5
# Safe                           74                      62         22
#
# GICS_Sector           Real Estate  Utilities
# Cluster_Hierarchical
# Moderate                        0          0
# Risky                           1          1
# Safe                           29         30
#
# Example Companies per Cluster:
# Moderate: ['ACGL', 'AFL', 'AIG', 'AIZ', 'AJG']
# Risky: ['AES', 'ALB', 'AMCR', 'APA', 'BWA']
# Safe: ['A', 'AAPL', 'ABBV', 'ABNB', 'ABT']
#
# DBSCAN Cluster Interpretation:
# Cluster Centroids (Mean Feature Values):
#                  median_volatility  hist_volatility  mean_momentum  \
# Cluster_DBSCAN
# Moderate                    0.016            0.225          1.010
# Risky                       0.025            0.373          1.002
# Safe                        0.018            0.254          1.005
#
#                 mean_volume_norm  environmentScore  socialScore  \
# Cluster_DBSCAN
# Moderate                     0.0             1.542        9.688
# Risky                        0.0             8.103       10.059
# Safe                         0.0             5.966        8.685
#
#                 governanceScore  marketCap   beta  highestControversy  \
# Cluster_DBSCAN
# Moderate                  9.105     24.690  1.015               1.600
# Risky                     6.104     24.364  1.336               2.075
# Safe                      4.753     24.478  0.987               1.720
#
#                 GICS_Sector_encoded
# Cluster_DBSCAN
# Moderate                      8.912
# Risky                         5.650
# Safe                          4.936
#
# Sector Distribution per Cluster:
#  GICS_Sector     Communication Services  Consumer Discretionary  \
# Cluster_DBSCAN
# Moderate                             0                       0
# Risky                                7                      10
# Safe                                12                      40
#
# GICS_Sector     Consumer Staples  Energy  Financials  Health Care  \
# Cluster_DBSCAN
# Moderate                       0       0          55            0
# Risky                          6      17          14           12
# Safe                          29       5           0           47
#
# GICS_Sector     Industrials  Information Technology  Materials  Real Estate  \
# Cluster_DBSCAN
# Moderate                  0                       0          0            0
# Risky                     9                      17          8            1
# Safe                     66                      49         19           29
#
# GICS_Sector     Utilities
# Cluster_DBSCAN
# Moderate                0
# Risky                   5
# Safe                   26
#
# Example Companies per Cluster:
# Moderate: ['ACGL', 'AFL', 'AIG', 'AIZ', 'AJG']
# Risky: ['AAPL', 'ADM', 'AES', 'ALB', 'ALGN']
# Safe: ['A', 'ABBV', 'ABNB', 'ABT', 'ACN']
#
# Clustered data saved as 'clustered_companies_kmeans.csv'
#
# Clustered data saved as 'clustered_companies_hierarchical.csv'
#
# Clustered data saved as 'clustered_companies_dbscan.csv'
